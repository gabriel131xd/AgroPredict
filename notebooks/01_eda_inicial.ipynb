# %%
import pandas as pd
import numpy as np
import requests

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv"

df = pd.read_csv(url)

df.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
import pandas as pd

url = "https://portal.inmet.gov.br/uploads/dadoshistoricos/2025zip"

print("URL preparada")
# Out:
# URL preparada

# %%
import pandas as pd

df = pd.read_csv("../data/processed/petrolina_clima_tratado.csv")
df["data"] = pd.to_datetime(df["data"])

df.head()
# Out:
#         data  temperatura_maxima  temperatura_minima  precipitacao  \
# 0 2025-01-01                35.8                24.0           0.1
# 1 2025-01-02                36.2                24.6           0.0
# 2 2025-01-03                36.8                25.0           0.0
# 3 2025-01-04                36.9                25.0           0.0
# 4 2025-01-05                36.0                25.8           0.1
#
#    vento_maximo  umidade_media  radiacao_solar  evapotranspiracao
# 0          20.3             44           25.75               7.57
# 1          16.3             39           27.38               8.24
# 2          15.2             37           28.21               8.31
# 3          13.7             41           25.80               7.47
# 4          14.7             44           25.16               7.35

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))
plt.plot(df["data"], df["temperatura_maxima"])
plt.title("Temperatura máxima diária em Petrolina")
plt.xlabel("Data")
plt.ylabel("Temperatura máxima (°C)")
plt.show()
